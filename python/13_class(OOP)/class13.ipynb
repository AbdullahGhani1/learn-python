# %%
def obj1_speak():pass
def obj2_speak():pass

obj1_name : str = "Sir Zia"
obj2_name : str = "Muhammad Qasim"

# %% [markdown]
# ## OOP (Object Oriented Programming)
# * Class
#     * method
#         * first argument must be additional variable (self, this, or anything else)
#     * attribute
#         * connect with individual object
#     * class variables
#     * constructor
#         * def ```__init__(self,arg1, arg2)```
#
#     * Class variable
#         * this value use for all objects
#             * `ClassName.class_vriable`
#         *
# ```
# class ClassName():
#     class_variable1 : type = Value
# ```
#
#
# ## Syntax of class
# ```
# class ClassName():
#     pass
# ```

# %%
class Teacher():
    def __init__(self, teacher_id : int , teacher_name : str) -> None: # method/constructor
        self.name : str = teacher_name #self.attribute_name = value
        self.teacher_id : int  = teacher_id
        self.organization_name: str = "PIAIC"


    def speak(self, words : str )->None: # method
        print(f"{self.name} is speaking {words}")
    
    def teaching(self, subject : str )->None: # method
        print(f"{self.name} is teaching {subject}...!")

# %%
#
obj1 : Teacher = Teacher(1,"Sir Zia Khan") #intialize object->calling constructor __init__() method only this time
# obj1 = object, teacher class instance



obj2 : Teacher = Teacher(2, "Muhammad Qasim")

# %%
abc1 : Teacher = Teacher(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 abc1 : Teacher = Teacher(3)
#
# TypeError: Teacher.__init__() missing 1 required positional argument: 'teacher_name'

# %%
print(obj1.name)
print(obj1.teacher_id)
print(obj1.organization_name)

print(obj2.name)
print(obj2.teacher_id)
print(obj2.organization_name)
# Out:
# Sir Zia Khan
# 1
# PIAIC
# Muhammad Qasim
# 2
# PIAIC

# %%
obj1.teaching("Generative AI")
# Out:
# Sir Zia Khan is teaching Generative AI...!

# %%
obj2.teaching("Deep Learning")
# Out:
# Muhammad Qasim is teaching Deep Learning...!

# %%
dir(obj1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'name',
#  'organization_name',
#  'speak',
#  'teacher_id',
#  'teaching']

# %%
class Teacher():
    def __init__(this, teacher_id : int , teacher_name : str) -> None: # method/constructor
        this.name : str = teacher_name
        this.teacher_id = teacher_id
        this.organization_name = "PIAIC"


    def speak(this, words : str )->None: # method
        print(f"{this.name} is speaking {words}")
    
    def teaching(this, subject : str )->None: # method
        print(f"{this.name} is teaching {subject}...!")


obj1 : Teacher = Teacher(1,"Sir Zia Khan")
obj2 : Teacher = Teacher(2, "Muhammad Qasim")

# %% [markdown]
# # Class Variable
#
# * Class variable
# * this value use for all objects
#     * `ClassName.class_variable`
#     * `object_name.class_variable`
#
#     ```
#     class ClassName():
#         class_variable1 : type = Value
#     ```

# %%
class Teacher():
    counter : int = 0 # Class variable1
    help_line_number : str = "0315-2968211" # class variable2

    def __init__(self, teacher_id : int , teacher_name : str) -> None: # method/constructor
        self.name : str = teacher_name #self.attribute_name = value
        self.teacher_id : int  = teacher_id
        self.organization_name: str = "PIAIC"
        Teacher.counter += 1


    def speak(self, words : str )->None: # method
        print(f"{self.name} is speaking {words}")
    
    def teaching(self, subject : str )->None: # method
        print(f"{self.name} is teaching {subject}...!")

    def details(self)->None:
        information : str = f"""
Teacher name is {self.name}
our help line number is {Teacher.help_line_number}

"""
        print(information)


obj1 : Teacher = Teacher(1,"Sir Zia Khan")

print(Teacher.counter, obj1.counter)
# Out:
# 1 1

# %%
id(obj1)
# Out:
# 4417627216

# %%
obj2 : Teacher = Teacher(2, "Muhammad Qasim")
print(Teacher.counter, obj1.counter)
# Out:
# 2 2

# %%
id(obj2)
# Out:
# 4417255424

# %%
print(obj1.counter)
print(obj2.counter)
print(Teacher.counter)

print(obj1.help_line_number)
print(obj2.help_line_number)
print(Teacher.help_line_number)
# Out:
# 2
# 2
# 2
# 0315-2968211
# 0315-2968211
# 0315-2968211

# %%
obj1.details()
# Out:
# Teacher name is Sir Zia Khan
# our help line number is 0315-2968211

# %% [markdown]
# ## 1. Inheritance
#
# ```
# class ChileClass(ParentClass):
#     pass
# ```

# %%
class Parents():
    def __init__(self)->None:
        self.eye_color :str = "Brown"
        self.hair_color : str = "black"
    
    def speak(self,words:str)->None:
        print(f'Parent method speak: {words}')
    
    def watching(self, object_name : str)->None:
        print(f"You are looking {object_name}!") 

class  Child(Parents):
    pass

obj1 : Parents = Parents()
print(obj1.eye_color)
print(obj1.hair_color)
obj1.watching("match")
# Out:
# Brown
# black
# You are looking match!

# %%
class Parents():
    def __init__(self)->None:
        self.eye_color : str = "Brown"
        self.hair_color : str = "black"

    def speak(self, words: str)->None:
        print(f"Parent method speak: {words}")

    def watching(sef, object_name : str)->None:
        print(f"You are looking {object_name}!")


class Child(Parents):
    pass 



obj1 : Parents = Parents()
print(obj1.eye_color)
print(obj1.hair_color)
obj1.speak("Pakistan zinda bad!")
obj1.watching("TV")

print("======Child object=======")
### Child object 

obj2 : Child = Child()
print(obj2.watching("Cenima"))
print(obj2.speak("Hello World"))
print(obj2.eye_color)
print(obj2.hair_color)
# Out:
# Brown
# black
# Parent method speak: Pakistan zinda bad!
# You are looking TV!
# ======Child object=======
# You are looking Cenima!
# None
# Parent method speak: Hello World
# None
# Brown
# black

# %%
class Parents():
    def __init__(self)->None:
        self.eye_color : str = "Brown"
        self.hair_color : str = "black"

    def speak(self, words: str)->None:
        print(f"Parent method speak: {words}")

    def watching(sef, object_name : str)->None:
        print(f"You are looking {object_name}!")


class Child(Parents):
    def teaching(self, subject : str = None)->None:
        print(f'Child method for teaching : {subject}')
     


obj1 : Parents = Parents()
print(obj1.eye_color)
print(obj1.hair_color)
obj1.speak("Pakistan zinda bad!")
obj1.watching("TV")


print("======Child object=======")
### Child object 

obj2 : Child = Child()
obj2.watching("Cenima")
obj2.speak("Hello World")
print(obj2.eye_color)
print(obj2.hair_color)
obj2.teaching("Generative AI")
# Out:
# Brown
# black
# Parent method speak: Pakistan zinda bad!
# You are looking TV!
# ======Child object=======
# You are looking Cenima!
# Parent method speak: Hello World
# Brown
# black
# Child method for teaching : Generative AI

# %%
class Employee():
    def __init__(self, name:str) -> None:
        self.name : str = name
        self.education : str  = ""
        self.department : str = ""

class Designer(Employee):
    def __init__(self, title : str, name: str) -> None:
        super().__init__(name)

        self.title : str = title


class Developer(Employee):
    def __init__(self, title: str, name: str) -> None:
        super().__init__(name)
        self.title: str = title
        self.programming_skills : list[str] = ["python"]



designe1 : Designer = Designer("Animation Artist","Asif Khan")

dev1 : Developer = Developer("GenAI Engineer","Isfahan")

print(designe1.name)

print(dev1.programming_skills,dev1.name)
# Out:
# Asif Khan
# ['python'] Isfahan

# %%
from typing import List

class Employee:
    def __init__(self, name: str) -> None:
        self.name: str = name
        self.education: str = ""
        self.department: str = ""

class Designer(Employee):
    def __init__(self, title: str, name: str) -> None:
        super().__init__(name)
        self.title: str = title

class Developer(Employee):
    def __init__(self, title: str, name: str) -> None:
        super().__init__(name)
        self.title: str = title
        self.programming_skills: List[str] = ["python"]

designer1: Designer = Designer("Animation Artist", "Asif Khan")
dev1: Developer = Developer("GenAI Engineer", "John Doe")

print(designer1.title)  # Output: Animation Artist
print(dev1.programming_skills)  # Output: ['python']
# Out:
# Animation Artist
# ['python']

# %% [markdown]
# ## 1. Encapsulation
# Encapsulation: The bundling of data with the methods that operate on that data. It restricts direct access to some of an object's components and can prevent the accidental modification of data.
# ## 2. Abstraction
# Abstraction: The concept of hiding the complex reality while exposing only the necessary parts. It helps to reduce programming complexity and effort.
# ## 3. Inheritance
# Inheritance: A mechanism wherein a new class inherits properties and behavior (methods) from another class. This helps to create a new class based on an existing class.
# ## 4. Polymorphism
# Polymorphism: The ability of different classes to respond to the same message (method call) in different ways. This allows for code to work with objects of various classes as if they were objects of a common superclass.

# %% [markdown]
# ### MultiClass Inheritance

# %%
class Mother:
    def __init__(self,name:str)->None:
        self.name:str = name
        self.eye_color:str =  "brown"
    
    def speaking(self,words:str)->str:
        return f"Mother Speaking function {words}"
    
class Father:
    def __init__(self,name:str)->None:
         self.name:str = name
         self.height:str =  "5.6 Feet"
    
    def speaking(self,words:str)->str:
        return f"Father Speaking function {words}"

class Child(Father,Mother):
    def __init__(self,mother_name:str,father_name:str,child_name:str)->None:
        Mother.__init__(self,mother_name)
        Father.__init__(self,father_name)
        self.child_name:str = child_name



abdullah:Child = Child("Yasmin","Abdul Ghani","Abdullah Ghani")
    
print(f"object height {abdullah.height}")
print(abdullah.speaking("Pakistan zinda bad"))
# Out:
# object height 5.6 Feet
# Father Speaking function Pakistan zinda bad

# %%
dir(abdullah)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'child_name',
#  'eye_color',
#  'height',
#  'name',
#  'speaking']

# %%
class Adder():
    def add(self,x:int,y:int)->int:
        return x + y
    
    def add(self,x:float,y:float)->float:
         return x + y
    
obj: Adder = Adder()
print(obj.add(3,4))
print(obj.add(3.3,4.3))
# Out:
# 7
# 7.6

# %% [markdown]
# ### Overloading

# %%
from typing import Union, overload

class Adder:
    @overload
    def add(self, x:int, y:int)->int:
        ...
    
    @overload
    def add(self, x:float, y:float)->float:
        ...
    
    @overload
    def add(self, x:str, y:str)->str:
        ...
    
    def add(self, x:Union[str,int,float],y:Union[str,int,float])-> Union[str,int,float]:
        if isinstance(x,int) and isinstance(y,int):
            return x+y
        elif isinstance(x,float) and isinstance(y,float):
            return x + y
        elif isinstance(x,str) and isinstance(y,str):
            return x + y
        else:
            raise TypeError("Invalid argument types!")

# %%
adder =Adder()

result1 = adder.add(2,3)
result2 = adder.add(2.4,3.5)
print(result1)
print(result2)
# Out:
# 5
# 5.9

# %% [markdown]
# ### Polymorphisum and overiding

# %%
class Animal():
    def eating(self,food:str)->None:
        print(f"Animal is eating {food}")

class Bird(Animal):
    def eating(self,food:str)->None:
        print(f"Bird is eating {food}")


bird: Bird = Bird()
bird.eating("bread")

animal: Animal = Animal()
animal.eating("grass")
# Out:
# Bird is eating bread
# Animal is eating grass

# %%
animal: Animal = Bird() # P
animal.eating("grass")
# Out:
# Bird is eating grass

# %%
print(type(animal))
# Out:
# <class '__main__.Bird'>

# %% [markdown]
# ### Static Methods

# %%
class MathOperation:
    counter: int = 100
    organization: str = "PIAIC"

    @staticmethod
    def add(x:int,y:int)->int:
        """Add two numbers"""
        return x+y
    @staticmethod
    def multiply(x:int,y:int)->int:
        """Multiply two numbers"""
        return x*y


result_add = MathOperation.add(20,2)
result_mul = MathOperation.multiply(10,2)

print("Addition:",result_add)
print("Multiplication:",result_mul)

print("Static variable or Class Variable",MathOperation.organization)
# Out:
# Addition: 22
# Multiplication: 20
# Static variable or Class Variable PIAIC

# %% [markdown]
# ### Everything is Object

# %%
class Human():
    def eating(self,food:str)->None:
        print(f"Human is eating {food}")

obj1: Human = Human()
obj1.eating("Biryani")
# Out:
# Human is eating Biryani

# %%
class Human1(object):
    def eating(self,food:str)->None:
        print(f"Human is eating {food}")

obj2: Human1 = Human1()
obj2.eating("Biryani")
# Out:
# Human is eating Biryani

# %%
dir(obj1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'eating']

# %%
dir(object)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# ### Callable

# %%
class SampleClass:
    def method(self):
        print("You called method()!")

print(type(SampleClass))
# Out:
# <class 'type'>

# %%
class NonCallable:
    def __call__(self):
        raise TypeError("not really callable")
    
instance: NonCallable = NonCallable()

callable(instance)
# Out:
# True

# %%
instance()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 instance()
#
# Cell In[44], line 3, in NonCallable.__call__(self)
#       2 def __call__(self):
# ----> 3     raise TypeError("not really callable")
#
# TypeError: not really callable

# %%
class PowerFactory:
    def __init__(self,exponent:int=2)->None:
        self.exponent = exponent

    def __call__(self,base:int)->int:
        return base**self.exponent
    
a: PowerFactory = PowerFactory()
a.exponent
# Out:
# 2

# %%
print(a(2))
print(a(4))
print(a(6))
# Out:
# 4
# 16
# 36

# %%
class CumulativeAverager():
    def __init__(self)->None:
        self.data: list[int] = []

    def __call__(self,new_value:int):
        self.data.append(new_value)
        print(self.data)
        return sum(self.data) / len(self.data)
    
stream_average: CumulativeAverager = CumulativeAverager()

# %%
print(stream_average(12))
print(stream_average(11))
print(stream_average(10))
print(stream_average(9))
# Out:
# [12]
# 12.0
# [12, 11]
# 11.5
# [12, 11, 10]
# 11.0
# [12, 11, 10, 9]
# 10.5

# %%
from math import factorial


class Factorial:
    def __init__(self):
        self.cache: dict[int, int] = {0:1,1:1}
    
    def __call__(self,number:int)->int:
        if number not in self.cache:
            self.cache[number] = number * self(number-1)
        return self.cache[number]


factorial = Factorial()
factorial.cache
# Out:
# {0: 1, 1: 1}

# %%
factorial(4)
factorial.cache
# Out:
# {0: 1, 1: 1, 2: 2, 3: 6, 4: 24}

# %%
from genai import ExecutionTimer

# %%
@ExecutionTimer
def square_numbers(numbers: list[int]) -> list[int]:
    return [number ** 2 for number in numbers]

square_numbers(list(range(10)))
# Out:
# square_numbers() took 0.0022 ms
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# ### Access Modifier

# %%
class Piaic():
    def __init__(self):
        self.piaic_helpline: str = "0800"
        self._total_expense: int = 6000000 # _ protected
        self.__test_announcement : str = " 5 Nov 2023" # __ private



abdullah: Piaic = Piaic()
print(abdullah.piaic_helpline)
# Out:
# 0800

# %%
abdullah.piaic_helpline = '0300-8108534' ## accessing public

print(abdullah.piaic_helpline)
# Out:
# 0300-8108534

# %%
abdullah._total_expense
# Out:
# 6000000

# %%
abdullah._total_expense ## accessing Protected
# Out:
# 6000000

# %%
abdullah.__test_announcement ## accessing private
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 abdullah.__test_announcement
#
# AttributeError: 'Piaic' object has no attribute '__test_announcement'

# %%
abdullah._Piaic__test_announcement
# Out:
# ' 5 Nov 2023'

# %%
class StudentLogin():

    def __init__(self)->None:
        self.__username: str = "Admin"
        self.__password: str = "Admin"

    def __db_connectivity(self, user: str, password: str)->str:
        print("Successfully Connected")
        if user == self.__username and password == self.__password:
            return "Valid user"
        else:
            return "Invalid user"
        
    def update_password(self,password:str):
        self.__password = password
        
    def student_login(self, user: str, pwd: str)->None:
        message = self.__db_connectivity(user,pwd)
        print(message)

    def display_information(self):
        print(f"Hello Dear, {self.__username} and password {self.__password}")


abdullah : StudentLogin = StudentLogin()

# %%
abdullah.__password
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 abdullah.__password
#
# AttributeError: 'StudentLogin' object has no attribute '__password'

# %%
abdullah.display_information()
# Out:
# Hello Dear, Admin and password Admin

# %%
abdullah.update_password("Asna@291")

# %%
abdullah.display_information()
# Out:
# Hello Dear, Admin and password Asna@291

# %% [markdown]
# ## __str__

# %%
class Teacher():
    def __init__(self,name:str)->None:
        self.name: str = name
    
    def __str__(self)->str:
        return f"Teacher name is {self.name}"
    
sir_zia: Teacher = Teacher("sir zia")

print(sir_zia)
# Out:
# Teacher name is sir zia

# %% [markdown]
# ### Abstract Class

# %%
from abc import ABC,abstractmethod


class Animal(ABC):

    @abstractmethod
    def eat(self,food:str)->str:
        ...

class Cat(Animal):

    def __init__(self)->None:
        super().__init__() #parent

    def eat(self, food: str)->str:
        return f"Cat is eating {food}"

abdullah: Cat = Cat()

print(abdullah.eat("food"))
# Out:
# Cat is eating food

# %%
from typing import Union
class Duck():
    def quack(self)->str:
        return 'Quack!'

class Person():
    def quack(self)->str:
        return ''

def in_the_forest(malard:Union[Duck,Person]):
    print(malard.quack())

donald: Duck = Duck()
john: Person = Person()
in_the_forest(donald)
in_the_forest(john)
# Out:
# Quack!

# %% [markdown]
# ## Duck Typing

# %%
class Duck:
    def quack(self)->str:
        return 'Quack!'

class Person:
    def quack(self)->str:
        return ''

def in_the_forest(malard):
    print(malard.quack())

donald: Duck = Duck()
john: Person = Person()
in_the_forest(donald)
in_the_forest(john)
# Out:
# Quack!
