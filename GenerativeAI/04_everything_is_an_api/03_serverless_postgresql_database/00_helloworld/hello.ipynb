# %% [markdown]
# # Connect an SQLAlchemy application to Neon
#
# https://neon.tech/docs/guides/sqlalchemy
#
# Code:
#
# https://neon.tech/docs/guides/sqlalchemy#create-an-sqlalchemy-engine-for-your-neon-project

# %%
# %pip install psycopg2-binary SQLAlchemy
# Out:
# Collecting psycopg2-binary
#   Using cached psycopg2_binary-2.9.10-cp312-cp312-macosx_14_0_arm64.whl.metadata (4.9 kB)
# Collecting SQLAlchemy
#   Downloading sqlalchemy-2.0.42-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/python12/lib/python3.12/site-packages (from SQLAlchemy) (4.14.1)
# Using cached psycopg2_binary-2.9.10-cp312-cp312-macosx_14_0_arm64.whl (3.3 MB)
# Downloading sqlalchemy-2.0.42-cp312-cp312-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: SQLAlchemy, psycopg2-binary
# Successfully installed SQLAlchemy-2.0.42 psycopg2-binary-2.9.10
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Establishing Connectivity - the Engine
#
# https://docs.sqlalchemy.org/en/20/tutorial/engine.html

# %% [markdown]
# ### Get the Connection String
#
# Create a new project: https://console.neon.tech/app/projects/
#
# Select the new project, and go to Dashboad and copy connection string from here:
#
# ![Where to Copy Connection String From](connection_string.png)

# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine

load_dotenv()
# Out:
# True

# %%
# psql 'postgresql://k191612:3AueMsX1OSYt@ep-curly-mouse-38234397.us-east-2.aws.neon.tech/test1?sslmode=require'

# conn_str = f'postgresql://ziaukhan:abcdefghijklmnopqrst@ep-little-frog-313391.us-east-2.aws.neon.tech/neondb?sslmode=require'
 
conn_str = os.getenv("DB_CONNECT")

# %%
from sqlalchemy.engine.base import Engine
engine: Engine = create_engine(conn_str)

# %% [markdown]
# # Getting a Connection
#
# https://docs.sqlalchemy.org/en/20/tutorial/dbapi_transactions.html#getting-a-connection

# %%
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("select 'hello world'"))
    print(result.all())
# Out:
# [('hello world',)]
