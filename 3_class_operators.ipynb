# %%
# %pip install pandas

# %%
# %conda install lxml -y
# Out:
# Collecting package metadata (current_repodata.json): | DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# | DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# / DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/osx-arm64/current_repodata.json HTTP/1.1" 304 0
# - DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-arm64/current_repodata.json HTTP/1.1" 304 0
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.10.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/abdullahghani/anaconda3/envs/python12
#
#   added / updated specs:
#     - lxml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     icu-73.1                   |       h313beb8_0        25.4 MB
#     libxml2-2.10.4             |       h0dcf63f_1         639 KB
#     libxslt-1.1.37             |       h80987f9_1         238 KB
#     lxml-4.9.3                 |  py312h50ffb84_0         1.2 MB
#     ------------------------------------------------------------
#                                            Total:        27.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   icu                pkgs/main/osx-arm64::icu-73.1-h313beb8_0
#   libiconv           pkgs/main/osx-arm64::libiconv-1.16-h1a28f6b_2
#   libxml2            pkgs/main/osx-arm64::libxml2-2.10.4-h0dcf63f_1
#   libxslt            pkgs/main/osx-arm64::libxslt-1.1.37-h80987f9_1
#   lxml               pkgs/main/osx-arm64::lxml-4.9.3-py312h50ffb84_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2023.7.2~ --> pkgs/main::ca-certificates-2023.08.22-hca03da5_0
#
#
#
# Downloading and Extracting Packages
# libxml2-2.10.4       | 639 KB    |                                       |   0%
# libxslt-1.1.37       | 238 KB    |                                       |   0%
#
# icu-73.1             | 25.4 MB   |                                       |   0%
#
#
# lxml-4.9.3           | 1.2 MB    |                                       |   0% DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-arm64/libxml2-2.10.4-h0dcf63f_1.conda HTTP/1.1" 200 654104
# libxml2-2.10.4       | 639 KB    | ####6                                 |  13% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-arm64/libxslt-1.1.37-h80987f9_1.conda HTTP/1.1" 200 243217
#
# libxslt-1.1.37       | 238 KB    | ##4                                   |   7%
# libxslt-1.1.37       | 238 KB    | ############4                         |  34% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-arm64/icu-73.1-h313beb8_0.conda HTTP/1.1" 200 26609848
#
#
# icu-73.1             | 25.4 MB   |                                       |   0%
#
# libxml2-2.10.4       | 639 KB    | #######4                              |  20% DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-arm64/lxml-4.9.3-py312h50ffb84_0.conda HTTP/1.1" 200 1278326
#
#
#
# lxml-4.9.3           | 1.2 MB    | 4                                     |   1%
#
#
# lxml-4.9.3           | 1.2 MB    | ##8                                   |   8%
# libxml2-2.10.4       | 639 KB    | #########2                            |  25%
# libxml2-2.10.4       | 639 KB    | ###########1                          |  30%
# libxml2-2.10.4       | 639 KB    | ############9                         |  35%
#
# icu-73.1             | 25.4 MB   | 1                                     |   0%
# libxslt-1.1.37       | 238 KB    | ##################################### | 100%
# libxslt-1.1.37       | 238 KB    | ##################################### | 100%
#
#
# libxml2-2.10.4       | 639 KB    | #############9                        |  38%
#
# icu-73.1             | 25.4 MB   | 2                                     |   1%
#
#
# lxml-4.9.3           | 1.2 MB    | #######1                              |  19%
#
# libxml2-2.10.4       | 639 KB    | ##########################8           |  73%
#
#
# libxml2-2.10.4       | 639 KB    | #################################3    |  90%
#
#
# libxml2-2.10.4       | 639 KB    | ##################################### | 100%
#
# icu-73.1             | 25.4 MB   | 8                                     |   2%
#
# icu-73.1             | 25.4 MB   | #                                     |   3%
#
#
# lxml-4.9.3           | 1.2 MB    | #############2                        |  36%
#
# icu-73.1             | 25.4 MB   | #1                                    |   3%
#
#
# lxml-4.9.3           | 1.2 MB    | ##############7                       |  40%
#
#
# lxml-4.9.3           | 1.2 MB    | #################                     |  46%
#
# icu-73.1             | 25.4 MB   | #2                                    |   4%
#
# icu-73.1             | 25.4 MB   | #4                                    |   4%
#
#
# lxml-4.9.3           | 1.2 MB    | ##################4                   |  50%
#
# icu-73.1             | 25.4 MB   | #5                                    |   4%
#
#
# lxml-4.9.3           | 1.2 MB    | ###################4                  |  53%
#
#
# lxml-4.9.3           | 1.2 MB    | #####################3                |  58%
#
# icu-73.1             | 25.4 MB   | #6                                    |   4%
#
# icu-73.1             | 25.4 MB   | #9                                    |   5%
#
# icu-73.1             | 25.4 MB   | ##                                    |   5%
#
#
# lxml-4.9.3           | 1.2 MB    | ######################2               |  60%
#
# icu-73.1             | 25.4 MB   | ##1                                   |   6%
#
#
# lxml-4.9.3           | 1.2 MB    | #######################2              |  63%
#
# icu-73.1             | 25.4 MB   | ##2                                   |   6%
#
# icu-73.1             | 25.4 MB   | ##3                                   |   6%
#
#
# lxml-4.9.3           | 1.2 MB    | ########################1             |  65%
#
# icu-73.1             | 25.4 MB   | ##3                                   |   6%
#
# icu-73.1             | 25.4 MB   | ##4                                   |   7%
#
# icu-73.1             | 25.4 MB   | ##4                                   |   7%
#
#
# lxml-4.9.3           | 1.2 MB    | #########################1            |  68%
#
# icu-73.1             | 25.4 MB   | ##5                                   |   7%
#
#
# lxml-4.9.3           | 1.2 MB    | #########################6            |  69%
#
# icu-73.1             | 25.4 MB   | ##6                                   |   7%
#
#
# lxml-4.9.3           | 1.2 MB    | ##########################            |  70%
#
# icu-73.1             | 25.4 MB   | ##7                                   |   7%
#
#
# lxml-4.9.3           | 1.2 MB    | ###########################           |  73%
#
# icu-73.1             | 25.4 MB   | ##8                                   |   8%
#
#
# lxml-4.9.3           | 1.2 MB    | ###########################5          |  74%
#
# icu-73.1             | 25.4 MB   | ##8                                   |   8%
#
#
# lxml-4.9.3           | 1.2 MB    | ############################4         |  77%
#
# icu-73.1             | 25.4 MB   | ##9                                   |   8%
#
#
# lxml-4.9.3           | 1.2 MB    | ############################9         |  78%
#
# icu-73.1             | 25.4 MB   | ###                                   |   8%
#
#
# lxml-4.9.3           | 1.2 MB    | #############################4        |  79%
#
# icu-73.1             | 25.4 MB   | ###                                   |   8%
#
# icu-73.1             | 25.4 MB   | ###1                                  |   8%
#
#
# lxml-4.9.3           | 1.2 MB    | #############################8        |  81%
#
# icu-73.1             | 25.4 MB   | ###2                                  |   9%
#
#
# lxml-4.9.3           | 1.2 MB    | ##############################8       |  83%
#
# icu-73.1             | 25.4 MB   | ###3                                  |   9%
#
# icu-73.1             | 25.4 MB   | ###3                                  |   9%
#
#
# lxml-4.9.3           | 1.2 MB    | ###############################7      |  86%
#
#
# lxml-4.9.3           | 1.2 MB    | ################################2     |  87%
#
# icu-73.1             | 25.4 MB   | ###4                                  |   9%
#
# icu-73.1             | 25.4 MB   | ###5                                  |  10%
#
# icu-73.1             | 25.4 MB   | ###5                                  |  10%
#
# icu-73.1             | 25.4 MB   | ###6                                  |  10%
#
# icu-73.1             | 25.4 MB   | ###7                                  |  10%
#
# icu-73.1             | 25.4 MB   | ###7                                  |  10%
#
# icu-73.1             | 25.4 MB   | ###8                                  |  10%
#
# icu-73.1             | 25.4 MB   | ####                                  |  11%
#
#
# lxml-4.9.3           | 1.2 MB    | ################################7     |  88%
#
# icu-73.1             | 25.4 MB   | ####1                                 |  11%
#
# icu-73.1             | 25.4 MB   | ####2                                 |  11%
#
#
# lxml-4.9.3           | 1.2 MB    | ##################################1   |  92%
#
# icu-73.1             | 25.4 MB   | ####3                                 |  12%
#
#
# lxml-4.9.3           | 1.2 MB    | ###################################   |  95%
#
# icu-73.1             | 25.4 MB   | ####4                                 |  12%
#
# icu-73.1             | 25.4 MB   | ####6                                 |  12%
#
# icu-73.1             | 25.4 MB   | ####7                                 |  13%
#
#
# lxml-4.9.3           | 1.2 MB    | ####################################  |  97%
#
# icu-73.1             | 25.4 MB   | ####8                                 |  13%
#
#
# lxml-4.9.3           | 1.2 MB    | ##################################### | 100%
#
# icu-73.1             | 25.4 MB   | ####9                                 |  13%
#
# icu-73.1             | 25.4 MB   | #####1                                |  14%
#
# icu-73.1             | 25.4 MB   | #####2                                |  14%
#
# icu-73.1             | 25.4 MB   | #####3                                |  15%
#
# icu-73.1             | 25.4 MB   | #####5                                |  15%
#
# icu-73.1             | 25.4 MB   | #####7                                |  16%
#
# icu-73.1             | 25.4 MB   | #####9                                |  16%
#
# icu-73.1             | 25.4 MB   | ######                                |  16%
#
# icu-73.1             | 25.4 MB   | ######1                               |  17%
#
# icu-73.1             | 25.4 MB   | ######3                               |  17%
#
# icu-73.1             | 25.4 MB   | ######4                               |  18%
#
# icu-73.1             | 25.4 MB   | ######6                               |  18%
#
# icu-73.1             | 25.4 MB   | ######8                               |  18%
#
# icu-73.1             | 25.4 MB   | ######9                               |  19%
#
# icu-73.1             | 25.4 MB   | #######1                              |  19%
#
# icu-73.1             | 25.4 MB   | #######2                              |  20%
#
# icu-73.1             | 25.4 MB   | #######4                              |  20%
#
# icu-73.1             | 25.4 MB   | #######5                              |  20%
#
# icu-73.1             | 25.4 MB   | #######6                              |  21%
#
# icu-73.1             | 25.4 MB   | ########3                             |  22%
#
# icu-73.1             | 25.4 MB   | ########5                             |  23%
#
# icu-73.1             | 25.4 MB   | ########8                             |  24%
#
# icu-73.1             | 25.4 MB   | #########                             |  25%
#
# icu-73.1             | 25.4 MB   | #########2                            |  25%
#
# icu-73.1             | 25.4 MB   | #########4                            |  25%
#
# icu-73.1             | 25.4 MB   | #########5                            |  26%
#
# icu-73.1             | 25.4 MB   | #########6                            |  26%
#
# icu-73.1             | 25.4 MB   | #########9                            |  27%
#
# icu-73.1             | 25.4 MB   | ##########1                           |  27%
#
# icu-73.1             | 25.4 MB   | ##########2                           |  28%
#
# icu-73.1             | 25.4 MB   | ##########4                           |  28%
#
# icu-73.1             | 25.4 MB   | ##########6                           |  29%
#
# icu-73.1             | 25.4 MB   | ##########7                           |  29%
#
# icu-73.1             | 25.4 MB   | ##########9                           |  30%
#
# icu-73.1             | 25.4 MB   | ###########                           |  30%
#
# icu-73.1             | 25.4 MB   | ###########2                          |  30%
#
# icu-73.1             | 25.4 MB   | ###########3                          |  31%
#
# icu-73.1             | 25.4 MB   | ###########5                          |  31%
#
# icu-73.1             | 25.4 MB   | ###########7                          |  32%
#
# icu-73.1             | 25.4 MB   | ###########8                          |  32%
#
# icu-73.1             | 25.4 MB   | ############                          |  33%
#
# icu-73.1             | 25.4 MB   | ############1                         |  33%
#
# icu-73.1             | 25.4 MB   | ############3                         |  33%
#
# icu-73.1             | 25.4 MB   | ############5                         |  34%
#
# icu-73.1             | 25.4 MB   | ############7                         |  34%
#
# icu-73.1             | 25.4 MB   | ############8                         |  35%
#
# icu-73.1             | 25.4 MB   | #############                         |  35%
#
# icu-73.1             | 25.4 MB   | #############2                        |  36%
#
# icu-73.1             | 25.4 MB   | #############4                        |  36%
#
# icu-73.1             | 25.4 MB   | #############5                        |  37%
#
# icu-73.1             | 25.4 MB   | #############7                        |  37%
#
# icu-73.1             | 25.4 MB   | #############8                        |  38%
#
# icu-73.1             | 25.4 MB   | ##############                        |  38%
#
# icu-73.1             | 25.4 MB   | ##############2                       |  38%
#
# icu-73.1             | 25.4 MB   | ##############4                       |  39%
#
# icu-73.1             | 25.4 MB   | ##############5                       |  39%
#
# icu-73.1             | 25.4 MB   | ##############7                       |  40%
#
# icu-73.1             | 25.4 MB   | ##############9                       |  40%
#
# icu-73.1             | 25.4 MB   | ###############1                      |  41%
#
# icu-73.1             | 25.4 MB   | ###############2                      |  41%
#
# icu-73.1             | 25.4 MB   | ###############4                      |  42%
#
# icu-73.1             | 25.4 MB   | ###############6                      |  42%
#
# icu-73.1             | 25.4 MB   | ###############8                      |  43%
#
# icu-73.1             | 25.4 MB   | ################                      |  43%
#
# icu-73.1             | 25.4 MB   | ################1                     |  44%
#
# icu-73.1             | 25.4 MB   | ################3                     |  44%
#
# icu-73.1             | 25.4 MB   | ################4                     |  45%
#
# icu-73.1             | 25.4 MB   | ################6                     |  45%
#
# icu-73.1             | 25.4 MB   | ################7                     |  45%
#
# icu-73.1             | 25.4 MB   | ################9                     |  46%
#
# icu-73.1             | 25.4 MB   | #################                     |  46%
#
# icu-73.1             | 25.4 MB   | #################1                    |  46%
#
# icu-73.1             | 25.4 MB   | #################3                    |  47%
#
# icu-73.1             | 25.4 MB   | #################4                    |  47%
#
# icu-73.1             | 25.4 MB   | #################4                    |  47%
#
# icu-73.1             | 25.4 MB   | #################5                    |  48%
#
# icu-73.1             | 25.4 MB   | #################6                    |  48%
#
# icu-73.1             | 25.4 MB   | #################7                    |  48%
#
# icu-73.1             | 25.4 MB   | #################8                    |  48%
#
# icu-73.1             | 25.4 MB   | #################9                    |  48%
#
# icu-73.1             | 25.4 MB   | #################9                    |  49%
#
# icu-73.1             | 25.4 MB   | ##################                    |  49%
#
# icu-73.1             | 25.4 MB   | ##################1                   |  49%
#
# icu-73.1             | 25.4 MB   | ##################2                   |  49%
#
# icu-73.1             | 25.4 MB   | ##################3                   |  50%
#
# icu-73.1             | 25.4 MB   | ##################4                   |  50%
#
# icu-73.1             | 25.4 MB   | ##################5                   |  50%
#
# icu-73.1             | 25.4 MB   | ##################5                   |  50%
#
# icu-73.1             | 25.4 MB   | ##################7                   |  51%
#
# icu-73.1             | 25.4 MB   | ##################8                   |  51%
#
# icu-73.1             | 25.4 MB   | ##################9                   |  51%
#
# icu-73.1             | 25.4 MB   | ###################                   |  52%
#
# icu-73.1             | 25.4 MB   | ###################2                  |  52%
#
# icu-73.1             | 25.4 MB   | ###################3                  |  52%
#
# icu-73.1             | 25.4 MB   | ###################5                  |  53%
#
# icu-73.1             | 25.4 MB   | ###################6                  |  53%
#
# icu-73.1             | 25.4 MB   | ###################7                  |  53%
#
# icu-73.1             | 25.4 MB   | ###################8                  |  54%
#
# icu-73.1             | 25.4 MB   | ###################9                  |  54%
#
# icu-73.1             | 25.4 MB   | ###################9                  |  54%
#
# icu-73.1             | 25.4 MB   | ####################                  |  54%
#
# icu-73.1             | 25.4 MB   | ####################1                 |  55%
#
# icu-73.1             | 25.4 MB   | ####################2                 |  55%
#
# icu-73.1             | 25.4 MB   | ####################4                 |  55%
#
# icu-73.1             | 25.4 MB   | ####################5                 |  56%
#
# icu-73.1             | 25.4 MB   | ####################7                 |  56%
#
# icu-73.1             | 25.4 MB   | ####################8                 |  56%
#
# icu-73.1             | 25.4 MB   | ####################9                 |  57%
#
# icu-73.1             | 25.4 MB   | #####################                 |  57%
#
# icu-73.1             | 25.4 MB   | #####################2                |  57%
#
# icu-73.1             | 25.4 MB   | #####################3                |  58%
#
# icu-73.1             | 25.4 MB   | #####################4                |  58%
#
# icu-73.1             | 25.4 MB   | #####################5                |  58%
#
# icu-73.1             | 25.4 MB   | #####################6                |  59%
#
# icu-73.1             | 25.4 MB   | #####################8                |  59%
#
# icu-73.1             | 25.4 MB   | ######################                |  59%
#
# icu-73.1             | 25.4 MB   | ######################1               |  60%
#
# icu-73.1             | 25.4 MB   | ######################2               |  60%
#
# icu-73.1             | 25.4 MB   | ######################4               |  61%
#
# icu-73.1             | 25.4 MB   | ######################5               |  61%
#
# icu-73.1             | 25.4 MB   | ######################6               |  61%
#
# icu-73.1             | 25.4 MB   | ######################7               |  62%
#
# icu-73.1             | 25.4 MB   | ######################8               |  62%
#
# icu-73.1             | 25.4 MB   | ######################9               |  62%
#
# icu-73.1             | 25.4 MB   | #######################               |  62%
#
# icu-73.1             | 25.4 MB   | #######################2              |  63%
#
# icu-73.1             | 25.4 MB   | #######################3              |  63%
#
# icu-73.1             | 25.4 MB   | #######################4              |  63%
#
# icu-73.1             | 25.4 MB   | #######################5              |  64%
#
# icu-73.1             | 25.4 MB   | #######################6              |  64%
#
# icu-73.1             | 25.4 MB   | #######################7              |  64%
#
# icu-73.1             | 25.4 MB   | #######################8              |  64%
#
# icu-73.1             | 25.4 MB   | #######################9              |  65%
#
# icu-73.1             | 25.4 MB   | ########################1             |  65%
#
# icu-73.1             | 25.4 MB   | ########################2             |  66%
#
# icu-73.1             | 25.4 MB   | ########################3             |  66%
#
# icu-73.1             | 25.4 MB   | ########################5             |  66%
#
# icu-73.1             | 25.4 MB   | ########################6             |  67%
#
# icu-73.1             | 25.4 MB   | ########################8             |  67%
#
# icu-73.1             | 25.4 MB   | #########################             |  68%
#
# icu-73.1             | 25.4 MB   | #########################1            |  68%
#
# icu-73.1             | 25.4 MB   | #########################3            |  68%
#
# icu-73.1             | 25.4 MB   | #########################4            |  69%
#
# icu-73.1             | 25.4 MB   | #########################6            |  69%
#
# icu-73.1             | 25.4 MB   | #########################8            |  70%
#
# icu-73.1             | 25.4 MB   | #########################9            |  70%
#
# icu-73.1             | 25.4 MB   | ##########################1           |  71%
#
# icu-73.1             | 25.4 MB   | ##########################2           |  71%
#
# icu-73.1             | 25.4 MB   | ##########################4           |  71%
#
# icu-73.1             | 25.4 MB   | ##########################5           |  72%
#
# icu-73.1             | 25.4 MB   | ##########################6           |  72%
#
# icu-73.1             | 25.4 MB   | ##########################8           |  73%
#
# icu-73.1             | 25.4 MB   | ###########################           |  73%
#
# icu-73.1             | 25.4 MB   | ###########################1          |  73%
#
# icu-73.1             | 25.4 MB   | ###########################2          |  74%
#
# icu-73.1             | 25.4 MB   | ###########################4          |  74%
#
# icu-73.1             | 25.4 MB   | ###########################4          |  74%
#
# icu-73.1             | 25.4 MB   | ###########################5          |  75%
#
# icu-73.1             | 25.4 MB   | ###########################7          |  75%
#
# icu-73.1             | 25.4 MB   | ###########################8          |  75%
#
# icu-73.1             | 25.4 MB   | ###########################9          |  76%
#
# icu-73.1             | 25.4 MB   | ############################          |  76%
#
# icu-73.1             | 25.4 MB   | ############################1         |  76%
#
# icu-73.1             | 25.4 MB   | ############################3         |  77%
#
# icu-73.1             | 25.4 MB   | ############################4         |  77%
#
# icu-73.1             | 25.4 MB   | ############################5         |  77%
#
# icu-73.1             | 25.4 MB   | ############################7         |  78%
#
# icu-73.1             | 25.4 MB   | ############################8         |  78%
#
# icu-73.1             | 25.4 MB   | #############################         |  78%
#
# icu-73.1             | 25.4 MB   | #############################1        |  79%
#
# icu-73.1             | 25.4 MB   | #############################2        |  79%
#
# icu-73.1             | 25.4 MB   | #############################3        |  79%
#
# icu-73.1             | 25.4 MB   | #############################5        |  80%
#
# icu-73.1             | 25.4 MB   | #############################6        |  80%
#
# icu-73.1             | 25.4 MB   | #############################7        |  81%
#
# icu-73.1             | 25.4 MB   | #############################9        |  81%
#
# icu-73.1             | 25.4 MB   | ##############################        |  81%
#
# icu-73.1             | 25.4 MB   | ##############################2       |  82%
#
# icu-73.1             | 25.4 MB   | ##############################3       |  82%
#
# icu-73.1             | 25.4 MB   | ##############################4       |  82%
#
# icu-73.1             | 25.4 MB   | ##############################5       |  82%
#
# icu-73.1             | 25.4 MB   | ##############################5       |  83%
#
# icu-73.1             | 25.4 MB   | ##############################6       |  83%
#
# icu-73.1             | 25.4 MB   | ##############################7       |  83%
#
# icu-73.1             | 25.4 MB   | ##############################8       |  83%
#
# icu-73.1             | 25.4 MB   | ##############################9       |  84%
#
# icu-73.1             | 25.4 MB   | ###############################       |  84%
#
# icu-73.1             | 25.4 MB   | ###############################       |  84%
#
# icu-73.1             | 25.4 MB   | ###############################1      |  84%
#
# icu-73.1             | 25.4 MB   | ###############################2      |  85%
#
# icu-73.1             | 25.4 MB   | ###############################3      |  85%
#
# icu-73.1             | 25.4 MB   | ###############################4      |  85%
#
# icu-73.1             | 25.4 MB   | ###############################5      |  85%
#
# icu-73.1             | 25.4 MB   | ###############################6      |  86%
#
# icu-73.1             | 25.4 MB   | ###############################8      |  86%
#
# icu-73.1             | 25.4 MB   | ###############################9      |  86%
#
# icu-73.1             | 25.4 MB   | ################################      |  87%
#
# icu-73.1             | 25.4 MB   | ################################2     |  87%
#
# icu-73.1             | 25.4 MB   | ################################3     |  87%
#
# icu-73.1             | 25.4 MB   | ################################4     |  88%
#
# icu-73.1             | 25.4 MB   | ################################6     |  88%
#
# icu-73.1             | 25.4 MB   | ################################7     |  88%
#
# icu-73.1             | 25.4 MB   | ################################8     |  89%
#
# icu-73.1             | 25.4 MB   | ################################9     |  89%
#
# icu-73.1             | 25.4 MB   | #################################1    |  89%
#
# icu-73.1             | 25.4 MB   | #################################2    |  90%
#
# icu-73.1             | 25.4 MB   | #################################3    |  90%
#
# icu-73.1             | 25.4 MB   | #################################4    |  90%
#
# icu-73.1             | 25.4 MB   | #################################6    |  91%
#
# icu-73.1             | 25.4 MB   | #################################7    |  91%
#
# icu-73.1             | 25.4 MB   | #################################8    |  92%
#
# icu-73.1             | 25.4 MB   | ##################################    |  92%
#
#
# icu-73.1             | 25.4 MB   | ##################################2   |  93%
#
# icu-73.1             | 25.4 MB   | ##################################3   |  93%
#
# icu-73.1             | 25.4 MB   | ##################################4   |  93%
#
# icu-73.1             | 25.4 MB   | ##################################6   |  94%
#
# icu-73.1             | 25.4 MB   | ##################################7   |  94%
#
# icu-73.1             | 25.4 MB   | ##################################9   |  94%
#
# icu-73.1             | 25.4 MB   | ###################################   |  95%
#
# icu-73.1             | 25.4 MB   | ###################################1  |  95%
#
# icu-73.1             | 25.4 MB   | ###################################2  |  95%
#
# icu-73.1             | 25.4 MB   | ###################################3  |  96%
#
# icu-73.1             | 25.4 MB   | ###################################5  |  96%
#
# icu-73.1             | 25.4 MB   | ###################################6  |  96%
#
# icu-73.1             | 25.4 MB   | ###################################7  |  97%
#
# icu-73.1             | 25.4 MB   | ###################################9  |  97%
#
# icu-73.1             | 25.4 MB   | ####################################1 |  98%
#
# icu-73.1             | 25.4 MB   | ####################################2 |  98%
#
# icu-73.1             | 25.4 MB   | ####################################4 |  98%
#
# icu-73.1             | 25.4 MB   | ####################################5 |  99%
#
# icu-73.1             | 25.4 MB   | ####################################6 |  99%
#
# icu-73.1             | 25.4 MB   | ####################################8 |  99%
#
# icu-73.1             | 25.4 MB   | ####################################9 | 100%
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ## Python Arthametic Operations
# - Arithmetic operators
# - Assignment operators
# - Comparison operators
# - Logical operators
# - Identity operators
# - Membership operators
# - Bitwise operators

# %%
table= pd.read_html('https://www.w3schools.com/python/python_operators.asp')
table[0]
# Out:
#   Operator            Name Example    Try it
# 0        +        Addition   x + y  Try it »
# 1        -     Subtraction   x - y  Try it »
# 2        *  Multiplication   x * y  Try it »
# 3        /        Division   x / y  Try it »
# 4        %         Modulus   x % y  Try it »
# 5       **  Exponentiation  x ** y  Try it »
# 6       //  Floor division  x // y  Try it »

# %%
a: int = 7
b: int = 2

print(a+b)  # addition
print(a-b)  # sub
print(a*b)  # multiplication
print(a/b)  # division
# Out:
# 9
# 5
# 14
# 3.5

# %%
print(a%b) #modulus | reminder
# Out:
# 1

# %%
print(2**3) #power
# Out:
# 8

# %%
print(12//3)
# Out:
# 4

# %% [markdown]
# # Python Assignment Operator

# %%
table[1]
# Out:
#    Operator  Example     Same As    Try it
# 0         =    x = 5       x = 5  Try it »
# 1        +=   x += 3   x = x + 3  Try it »
# 2        -=   x -= 3   x = x - 3  Try it »
# 3        *=   x *= 3   x = x * 3  Try it »
# 4        /=   x /= 3   x = x / 3  Try it »
# 5        %=   x %= 3   x = x % 3  Try it »
# 6       //=  x //= 3  x = x // 3  Try it »
# 7       **=  x **= 3  x = x ** 3  Try it »
# 8        &=   x &= 3   x = x & 3  Try it »
# 9        |=   x |= 3   x = x | 3  Try it »
# 10       ^=   x ^= 3   x = x ^ 3  Try it »
# 11      >>=  x >>= 3  x = x >> 3  Try it »
# 12      <<=  x <<= 3  x = x << 3  Try it »

# %%
# Assign
a: int = 7
print(a)
a+=2  # a=a+2
print(a)
# Out:
# 7
# 9

# %%
# Assign
a: int = 7
print(a)
a-=2  # a=a-2
print(a)
# Out:
# 7
# 5

# %%
# Assign
a: int = 7
print(a)
a*=2  # a=a*2
print(a)
# Out:
# 7
# 14

# %%
# Assign
a: int = 7
print(a)
a/=2  # a=a/2
print(a)
# Out:
# 7
# 3.5

# %%
# Assign
a: int = 7
print(a)
a%=2  # a=a%2
print(a)
# Out:
# 7
# 1

# %%
# Assign
a: int = 7
print(a)
a:=2  # a=a+2
print(a)

# %% [markdown]
# ## Python Comparision Operator

# %%
table[2]

# %%
a : int =7
b : str = '7'
print(a==b)

# %%
chr(65)

# %%
ord('A')

# %%
ord('4')

# %%
ord('9')

# %%
ord('0')

# %%
ord('د')

# %%
ord('ل')
