# %% [markdown]
# # HTTP Requests
#
# We will use the simple book API to learn to call APIs:
#
# https://github.com/vdespa/introduction-to-postman-course/blob/main/simple-books-api.md
#
# Requests Documentation:
#
# https://requests.readthedocs.io/en/latest/
#
# Tutorial:
#
# https://ioflood.com/blog/python-requests/

# %%
import requests
from requests.models import Response
from requests.structures import CaseInsensitiveDict

# %% [markdown]
# ### Get Status

# %%
response: Response = requests.get('https://simple-books-api.glitch.me/status')
display("Response",response)

status_code : int = response.status_code
print("Status_code",status_code)

json_obj : dict = response.json()
print("Json_obj",json_obj, type(json_obj))

txt: str = response.text
print("response.text",txt,type(txt))

headers: CaseInsensitiveDict = response.headers
print("response.headers",headers)

print(response.status_code, response.json(), response.text, response.headers)
# Out:
# 'Response'
# <Response [200]>
# Status_code 200
# Json_obj {'status': 'OK'} <class 'dict'>
# response.text {"status":"OK"} <class 'str'>
# response.headers {'Content-Type': 'application/json', 'Content-Length': '15', 'Connection': 'keep-alive', 'Date': 'Sat, 09 Aug 2025 09:23:58 GMT', 'X-Amzn-Trace-Id': 'Root=1-689713ae-37b902365e7fc48677b4d0e5;Parent=7207f395b15047a4;Sampled=0;Lineage=1:9ee0f5ed:0', 'x-amzn-RequestId': 'a5cde2d9-34ae-49f1-add8-c9c734b59b8b', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Headers': 'Content-Type, Authorization, X-Amz-Date, X-Api-Key, X-Amz-Security-Token', 'x-amz-apigw-id': 'PCADUHNYoAMELwQ=', 'Access-Control-Allow-Methods': 'GET, POST, PUT, DELETE, OPTIONS, PATCH', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 206b3038ddc0ddd66821970b96dd4546.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'DXB52-P2', 'X-Amz-Cf-Id': 'HG_sC_4QoiEtfboUxBeE7HDFZTDTpKHF8zVBZOivB-TMq0Lhg9H8iA=='}
# ...

# %%
from requests.models import Response
from requests.structures import CaseInsensitiveDict

response: Response = requests.get('https://requests.readthedocs.io/en/latest/')
display("Response",response)

status_code : int = response.status_code
print("Status_code",status_code)

# json_obj : dict = response.json()
# print("Json_obj",json_obj, type(json_obj))

txt: str = response.text
print("response.text",txt,type(txt))

headers: CaseInsensitiveDict[str] = response.headers
print("response.headers",headers)
# Out:
# 'Response'
# <Response [200]>
# Status_code 200
# response.text <!DOCTYPE html>
#
# <html lang="en" data-content_root="./">
#   <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" /><meta name="viewport" content="width=device-width, initial-scale=1" />
#
#     <title>Requests: HTTP for Humans™ &#8212; Requests 2.32.4 documentation</title>
#     <link rel="stylesheet" type="text/css" href="_static/pygments.css?v=6625fa76" />
#     <link rel="stylesheet" type="text/css" href="_static/alabaster.css?v=1fe5e9f7" />
#     <script src="_static/documentation_options.js?v=23e4e8c7"></script>
#     <script src="_static/doctools.js?v=888ff710"></script>
#     <script src="_static/sphinx_highlight.js?v=dc90522c"></script>
#     <link rel="index" title="Index" href="genindex/" />
#     <link rel="search" title="Search" href="search/" />
#     <link rel="next" title="Installation of Requests" href="user/install/" />
#
# ...

# %% [markdown]
# ### Get List of Books

# %%
response: Response = requests.get('https://simple-books-api.glitch.me/books')

status_code : int = response.status_code
print(status_code)

json_obj : list[str] = response.json()
display(json_obj)


headers: CaseInsensitiveDict[str] = response.headers
display(headers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 response: Response = requests.get('https://simple-books-api.glitch.me/books')
#       3 status_code : int = response.status_code
#       4 print(status_code)
#
# NameError: name 'requests' is not defined

# %% [markdown]
# ### Get a Single Book

# %%
response: Response = requests.get('https://simple-books-api.glitch.me/books/1')

status_code : int = response.status_code
print(status_code)

json_obj : dict[str,str] = response.json()
print("Book :",json_obj)

headers: CaseInsensitiveDict[str] = response.headers
print(headers)
# Out:
# 200
# Book : {'id': 1, 'available': True, 'isbn': '1780899475', 'name': 'The Russian', 'current-stock': 12, 'price': 12.98, 'author': 'James Patterson and James O. Born', 'type': 'fiction'}
# {'Content-Type': 'application/json', 'Content-Length': '161', 'Connection': 'keep-alive', 'Date': 'Sat, 09 Aug 2025 09:24:02 GMT', 'X-Amzn-Trace-Id': 'Root=1-689713b2-1969449163dedde1400ef22b;Parent=08ce87e9406d60cc;Sampled=0;Lineage=1:9ee0f5ed:0', 'x-amzn-RequestId': '5efff6e3-77c4-4261-90ed-07847d1bbaa2', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Headers': 'Content-Type, Authorization, X-Amz-Date, X-Api-Key, X-Amz-Security-Token', 'x-amz-apigw-id': 'PCAD-FlCIAMEiCg=', 'Access-Control-Allow-Methods': 'GET, POST, PUT, DELETE, OPTIONS, PATCH', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 206b3038ddc0ddd66821970b96dd4546.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'DXB52-P2', 'X-Amz-Cf-Id': '6VhjS-vmNtslWNVUwvV1cX9roNTi0XHDkODpTKaAmrjsSLCfjaHiKQ=='}

# %% [markdown]
# ### API Authentication

# %%
data1  : dict[str,str]= {
   "clientName": "Abdullah",
   "clientEmail": "abdullahghani.dev@gmail.com"
}


response1: Response = requests.post('https://simple-books-api.glitch.me/api-clients', json = data1)

status_code : int = response1.status_code
print(status_code)

json_obj : dict[str,str] = response1.json()
print(json_obj)

# Dont know why we are receiving this error?

# Reason: Simple book API require body data in json format. So Here we will use json parameter instead of data parameter.

# %%
# Making post request with json parameter to send body data in json format

data: dict[str,str] = {
   "clientName": "qasim23",
   "clientEmail": "m.qasim32@gmail.com"
}

response1: Response = requests.post('https://simple-books-api.glitch.me/api-clients', json = data)

status_code : int = response1.status_code
print(status_code)#e232c09f3d1fcb27eac378535450bfd1ac489b607390938ec395b7aa1d5d151f

json_obj : dict[str,str] = response1.text
print(json_obj)
# Out:
# 201
# {"accessToken":"3d9c79db73b31f5b6c97bcac2bd7c2e8321f0e12f560e47562f87910a2b62a7c"}

# %% [markdown]
# ### Submit an order

# %%
from typing import Union
token: str = "3d9c79db73b31f5b6c97bcac2bd7c2e8321f0e12f560e47562f87910a2b62a7c"
# headers: dict[str,str] = {'Authorization': 'Bearer e9a3acb19c816774663d38bbded7c74b095f13245294a65e277623ffd16acf69'}
# headers: dict[str,str] = {'Authorization': 'Bearer e9a3acb19c816774663d38bbded7c74b095f13245294a65e277623ffd16acf69'}
headers: dict[str,str] = {'Authorization': f'Bearer {token}'} # last value




data1 : dict[str,Union[int,str]] = {
  "bookId": 2,
  "customerName": "qasim23"
}

response2: Response = requests.post('https://simple-books-api.glitch.me/orders', 
                                    headers=headers, 
                                    json=data1)

status_code : int = response2.status_code
print(status_code)

json_obj : dict = response2.text
print(json_obj)
# Out:
# 401
# {"error":"Missing Authorization header."}

# %% [markdown]
# ### Update an order

# %% [markdown]
# ### Update an order

# %%
headers: dict[str,str] = {'Authorization': 'Bearer 4ab4bfde54bea0eb852e97997ea6600ff063ff72fd0b17ffe0eb0676e7eaee53'}

orderId = "r4xjjswhJnQg4mxZjffdD"

data2 = {
  "customerName": "Qasim"
}

response3: Response = requests.patch(f'https://simple-books-api.glitch.me/orders/{orderId}', headers=headers, json = data2)

status_code : int = response3.status_code
print(status_code)


# PATCH requests updates the order and send 204 status code. So, we are not getting any response body.
# Out:
# 401

# %% [markdown]
# ### Delete an order

# %%
headers: dict = {'Authorization': 'Bearer 4ab4bfde54bea0eb852e97997ea6600ff063ff72fd0b17ffe0eb0676e7eaee53'}

orderId = "r4xjjswhJnQg4mxZjffdD"

response4: Response = requests.delete(f'https://simple-books-api.glitch.me/orders/{orderId}', headers = headers)

status_code : int = response4.status_code
print(status_code)

# DELETE request deletes the order and send 204 status code. So, we are not getting any response body.
